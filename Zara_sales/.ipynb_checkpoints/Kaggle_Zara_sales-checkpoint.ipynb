# %%
import pandas as pd
import seaborn as sns

sales_url = r"C:\Users\fomin\Analytics\Kaggle_datasets\Zara\zara_sales.csv"
sales = pd.read_csv(sales_url, sep = ';')

sales.head()
# Out:
#    Product ID Product Position Promotion Product Category Seasonal  \
# 0      185102            Aisle        No         Clothing       No
# 1      188771            Aisle        No         Clothing       No
# 2      180176          End-cap       Yes         Clothing      Yes
# 3      112917            Aisle       Yes         Clothing      Yes
# 4      192936          End-cap        No         Clothing      Yes
#
#    Sales Volume brand                                                url  \
# 0          2823  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1           654  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# 2          2220  Zara  https://www.zara.com/us/en/slim-fit-suit-jacke...
# 3          1568  Zara  https://www.zara.com/us/en/stretch-suit-jacket...
# 4          2942  Zara  https://www.zara.com/us/en/double-faced-jacket...
#
#                 sku                  name  \
# 0   272145190-250-2   BASIC PUFFER JACKET
# 1  324052738-800-46         TUXEDO JACKET
# 2  335342680-800-44  SLIM FIT SUIT JACKET
# 3  328303236-420-44   STRETCH SUIT JACKET
# 4   312368260-800-2   DOUBLE FACED JACKET
#
#                                          description   price currency  \
# 0  Puffer jacket made of tear-resistant ripstop f...   19.99      USD
# 1  Straight fit blazer. Pointed lapel collar and ...  169.00      USD
# 2  Slim fit jacket. Notched lapel collar. Long sl...  129.00      USD
# 3  Slim fit jacket made of viscose blend fabric. ...  129.00      USD
# 4  Jacket made of faux leather faux shearling wit...  139.00      USD
#
#                    scraped_at    terms section
# 0  2024-02-19T08:50:05.654618  jackets     MAN
# 1  2024-02-19T08:50:06.590930  jackets     MAN
# 2  2024-02-19T08:50:07.301419  jackets     MAN
# 3  2024-02-19T08:50:07.882922  jackets     MAN
# 4  2024-02-19T08:50:08.453847  jackets     MAN

# %%
sns.set(
    font_scale=2,
    style="whitegrid",
    rc={'figure.figsize':(20,7)}
        )

# %%
sales.isnull().sum()
# Out:
# Product ID          0
# Product Position    0
# Promotion           0
# Product Category    0
# Seasonal            0
# Sales Volume        0
# brand               0
# url                 0
# sku                 0
# name                1
# description         2
# price               0
# currency            0
# scraped_at          0
# terms               0
# section             0
# dtype: int64

# %%
sales.shape
# Out:
# (252, 16)

# %%
sales.columns = sales.columns.str.lower().str.replace(' ', '_')

# Привожу к удобному для работы виду названия колонок

# %%
sales['revenue_by_item'] = sales.sales_volume * sales.price

# Ввожу новый столбец, который описывает выручку с айтема - перемножив количество проданного товара на его цену

# %%
sales.head()
# Out:
#    product_id product_position promotion product_category seasonal  \
# 0      185102            Aisle        No         Clothing       No
# 1      188771            Aisle        No         Clothing       No
# 2      180176          End-cap       Yes         Clothing      Yes
# 3      112917            Aisle       Yes         Clothing      Yes
# 4      192936          End-cap        No         Clothing      Yes
#
#    sales_volume brand                                                url  \
# 0          2823  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1           654  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# 2          2220  Zara  https://www.zara.com/us/en/slim-fit-suit-jacke...
# 3          1568  Zara  https://www.zara.com/us/en/stretch-suit-jacket...
# 4          2942  Zara  https://www.zara.com/us/en/double-faced-jacket...
#
#                 sku                  name  \
# 0   272145190-250-2   BASIC PUFFER JACKET
# 1  324052738-800-46         TUXEDO JACKET
# 2  335342680-800-44  SLIM FIT SUIT JACKET
# 3  328303236-420-44   STRETCH SUIT JACKET
# 4   312368260-800-2   DOUBLE FACED JACKET
#
#                                          description   price currency  \
# 0  Puffer jacket made of tear-resistant ripstop f...   19.99      USD
# 1  Straight fit blazer. Pointed lapel collar and ...  169.00      USD
# 2  Slim fit jacket. Notched lapel collar. Long sl...  129.00      USD
# 3  Slim fit jacket made of viscose blend fabric. ...  129.00      USD
# 4  Jacket made of faux leather faux shearling wit...  139.00      USD
#
#                    scraped_at    terms section  revenue_by_item
# 0  2024-02-19T08:50:05.654618  jackets     MAN         56431.77
# 1  2024-02-19T08:50:06.590930  jackets     MAN        110526.00
# 2  2024-02-19T08:50:07.301419  jackets     MAN        286380.00
# 3  2024-02-19T08:50:07.882922  jackets     MAN        202272.00
# 4  2024-02-19T08:50:08.453847  jackets     MAN        408938.00

# %%
sales[['product_id', 'revenue_by_item']].sort_values('revenue_by_item')
# Out:
#      product_id  revenue_by_item
# 162      136738          4330.58
# 203      171776         21888.15
# 189      185307         21916.57
# 234      185774         22888.55
# 210      142257         23482.00
# ..          ...              ...
# 169      152563        434668.00
# 67       154016        447174.00
# 87       152723        481481.00
# 38       114877        649140.00
# 60       151925        651521.00
#
# [252 rows x 2 columns]

# %%
nunique_name = sales.groupby('name', as_index=False).agg({'revenue_by_item':'count'}).sort_values('revenue_by_item') \
    .rename(columns={'revenue_by_item':'counts_in_df'})

nunique_name.loc[nunique_name.counts_in_df > 1]
# Out:
#                                               name  counts_in_df
# 162                                    SUIT JACKET             2
# 186                              WOOL BLEND JACKET             2
# 160                                 SUEDE SNEAKERS             2
# 167                        TECHNICAL PADDED JACKET             2
# 0                  100% FEATHER FILL PUFFER JACKET             2
# 145                       STRETCH POCKET OVERSHIRT             2
# 13                                 BAGGY FIT JEANS             2
# 24                          BOUCLÉ TEXTURED JACKET             2
# 38                       CONTRASTING COLLAR JACKET             2
# 45           CROPPED BOMBER JACKET LIMITED EDITION             2
# 46                          CROPPED LEATHER JACKET             2
# 50                             DENIM BOMBER JACKET             2
# 58                    FAUX LEATHER BOXY FIT JACKET             2
# 60   FAUX LEATHER OVERSIZED JACKET LIMITED EDITION             2
# 65                               FAUX SUEDE JACKET             2
# 151                        STRUCTURED TEXT T-SHIRT             2
# 85                           JACQUARD DENIM JACKET             2
# 94                            LEATHER BIKER JACKET             2
# 77                     HERRINGBONE TEXTURED JACKET             2
# 106                            MULTIPIECE SNEAKERS             2
# 111       OVERSIZED CROPPED JACKET LIMITED EDITION             2
# 141                           SLIM FIT SUIT JACKET             2
# 113                           PADDED BOMBER JACKET             2
# 115                            PADDED DENIM JACKET             2
# 137                            RIBBED KNIT T-SHIRT             2
# 136                              RIB COLLAR JACKET             2
# 95                                  LEATHER JACKET             2
# 123                                  POCKET JACKET             2
# 22                                   BOMBER JACKET             3
# 39               CONTRASTING PATCHES BOMBER JACKET             3
# 163                      SUIT JACKET IN 100% LINEN             3
# 57                      FAUX LEATHER BOMBER JACKET             3
# 59                             FAUX LEATHER JACKET             3
# 61                      FAUX LEATHER PUFFER JACKET             3
# 64                        FAUX SUEDE BOMBER JACKET             3
# 83                         HOODED TECHNICAL JACKET             3
# 96                       LIGHTWEIGHT BOMBER JACKET             3
# 117                            PATCH BOMBER JACKET             4
# 124                               POCKET OVERSHIRT             4
# 118                                PLAID OVERSHIRT             6

# %%
# nunique_name = sales.groupby('name', as_index=False).agg({'revenue_by_item':'count'}).sort_values('revenue_by_item') \
#     .rename(columns={'revenue_by_item':'counts_in_df'})

# list_of_repeated_items_names = nunique_name.loc[nunique_name.counts_in_df > 1].name

# list_of_repeated_items_names

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales.groupby('name').filter(lambda x: len(x) == 1)
# Out:
#      product_id product_position promotion product_category seasonal  \
# 0        185102            Aisle        No         Clothing       No
# 1        188771            Aisle        No         Clothing       No
# 3        112917            Aisle       Yes         Clothing      Yes
# 4        192936          End-cap        No         Clothing      Yes
# 8        141861            Aisle       Yes         Clothing      Yes
# ..          ...              ...       ...              ...      ...
# 221      141330            Aisle        No         Clothing      Yes
# 223      155010            Aisle       Yes         Clothing      Yes
# 224      135857            Aisle        No         Clothing      Yes
# 225      147690            Aisle       Yes         Clothing       No
# 226      130321          End-cap       Yes         Clothing       No
#
#      sales_volume brand                                                url  \
# 0            2823  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1             654  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# 3            1568  Zara  https://www.zara.com/us/en/stretch-suit-jacket...
# 4            2942  Zara  https://www.zara.com/us/en/double-faced-jacket...
# 8            1916  Zara  https://www.zara.com/us/en/100-wool-suit-jacke...
# ..            ...   ...                                                ...
# 221          1915  Zara  https://www.zara.com/us/en/raised-text-t-shirt...
# 223           729  Zara  https://www.zara.com/us/en/semi-sheer-knit-shi...
# 224          2045  Zara  https://www.zara.com/us/en/viscose-blend-knit-...
# 225           881  Zara  https://www.zara.com/us/en/striped-jacquard-t-...
# 226          2093  Zara  https://www.zara.com/us/en/abstract-print-knit...
#
#                   sku                                   name  \
# 0     272145190-250-2                    BASIC PUFFER JACKET
# 1    324052738-800-46                          TUXEDO JACKET
# 3    328303236-420-44                    STRETCH SUIT JACKET
# 4     312368260-800-2                    DOUBLE FACED JACKET
# 8    313854165-401-46                  100% WOOL SUIT JACKET
# ..                ...                                    ...
# 221   323216369-922-2    RAISED TEXT T-SHIRT LIMITED EDITION
# 223   328232445-800-2  SEMI-SHEER KNIT SHIRT LIMITED EDITION
# 224   311297550-251-2             VISCOSE BLEND KNIT T-SHIRT
# 225   322909502-819-2               STRIPED JACQUARD T-SHIRT
# 226   320071210-802-2            ABSTRACT PRINT KNIT T-SHIRT
#
#                                            description   price currency  \
# 0    Puffer jacket made of tear-resistant ripstop f...   19.99      USD
# 1    Straight fit blazer. Pointed lapel collar and ...  169.00      USD
# 3    Slim fit jacket made of viscose blend fabric. ...  129.00      USD
# 4    Jacket made of faux leather faux shearling wit...  139.00      USD
# 8    Jacket made of Italian wool. Pointed lapel col...  169.00      USD
# ..                                                 ...     ...      ...
# 221  Full cut T-shirt with round neck and short sle...   39.90      USD
# 223  Slim fit shirt made of wrinkle effect fabric. ...   45.90      USD
# 224  Knit shirt in viscose blend fabric. Mock neck ...   45.90      USD
# 225  Relaxed fit T-shirt with round neck and short ...   39.90      USD
# 226  Cotton knit T-shirt. Round neck and short slee...   39.90      USD
#
#                      scraped_at     terms section  revenue_by_item
# 0    2024-02-19T08:50:05.654618   jackets     MAN         56431.77
# 1    2024-02-19T08:50:06.590930   jackets     MAN        110526.00
# 3    2024-02-19T08:50:07.882922   jackets     MAN        202272.00
# 4    2024-02-19T08:50:08.453847   jackets     MAN        408938.00
# 8    2024-02-19T08:50:10.880741   jackets     MAN        323804.00
# ..                          ...       ...     ...              ...
# 221  2024-02-19T08:56:32.570492  t-shirts     MAN         76408.50
# 223  2024-02-19T08:56:33.715892  t-shirts     MAN         33461.10
# 224  2024-02-19T08:56:34.269203  t-shirts     MAN         93865.50
# 225  2024-02-19T08:56:34.766636  t-shirts     MAN         35151.90
# 226  2024-02-19T08:56:35.255056  t-shirts     MAN         83510.70
#
# [154 rows x 17 columns]

# %%
sales.groupby('name', as_index=False).agg({'revenue_by_item':'sum'}).sort_values('revenue_by_item')
# Out:
#                                   name  revenue_by_item
# 78            HIGH COLLAR KNIT SWEATER          4330.58
# 51                         DENIM SHIRT         21888.15
# 15             BASIC 100% WOOL SWEATER         21916.57
# 21              BASIC SLIM FIT T-SHIRT         23482.00
# 134                     RETRO SNEAKERS         24885.09
# ..                                 ...              ...
# 136                  RIB COLLAR JACKET        685883.00
# 118                    PLAID OVERSHIRT        695369.00
# 57          FAUX LEATHER BOMBER JACKET        798852.60
# 163          SUIT JACKET IN 100% LINEN        816675.00
# 39   CONTRASTING PATCHES BOMBER JACKET        889308.00
#
# [194 rows x 2 columns]

# %%
sales.price.sort_values()
# Out:
# 189      7.99
# 162      7.99
# 140      9.99
# 139      9.99
# 249     12.99
#         ...
# 67     189.00
# 60     299.00
# 22     299.00
# 38     349.00
# 13     439.00
# Name: price, Length: 252, dtype: float64

# %%
is_null_df = sales.isnull()

row_with_null = is_null_df.any(axis=1)

rows_with_null = sales[row_with_null]

rows_with_null

# поиск строк, где есть хотя бы одно нулевое значение
# можно дропнуть эти строки из датафрейма, учтя выручку с товаров в них
# Out:
#     product_id product_position promotion product_category seasonal  \
# 60      151925          End-cap       Yes         Clothing      Yes
# 72      173576          End-cap       Yes         Clothing       No
#
#     sales_volume brand                                                url  \
# 60          2179  Zara  https://www.zara.com/us/en/vintage-effect-leat...
# 72          1838  Zara         https://www.zara.com/us/en/-p04310461.html
#
#                  sku                                  name description  price  \
# 60  320774184-800-97  VINTAGE EFFECT LEATHER BOMBER JACKET         NaN  299.0
# 72   336378923-700-2                                   NaN         NaN  129.0
#
#    currency                  scraped_at    terms section  revenue_by_item
# 60      USD  2024-02-19T08:50:43.543555  jackets     MAN         651521.0
# 72      USD  2024-02-19T08:50:54.476057  jackets     MAN         237102.0

# %%
ax = sns.barplot(x=sales.price.round(0), y=sales.revenue_by_item, width = 1)

ax.set_xticks(ax.get_xticks()[::2])

# кластеризуй эти данные по ценам, когда изучишь кластеризацию
# Out:
# [<matplotlib.axis.XTick at 0x24460e98af0>,
#  <matplotlib.axis.XTick at 0x24460e98ac0>,
#  <matplotlib.axis.XTick at 0x24460e986d0>,
#  <matplotlib.axis.XTick at 0x24460f4fc70>,
#  <matplotlib.axis.XTick at 0x24460f68760>,
#  <matplotlib.axis.XTick at 0x24460f68c70>,
#  <matplotlib.axis.XTick at 0x24460f69720>,
#  <matplotlib.axis.XTick at 0x24460f6a1d0>,
#  <matplotlib.axis.XTick at 0x24460f6ac80>,
#  <matplotlib.axis.XTick at 0x24460f4f5e0>,
#  <matplotlib.axis.XTick at 0x24460f691b0>,
#  <matplotlib.axis.XTick at 0x24460f6bd60>,
#  <matplotlib.axis.XTick at 0x24460f84bb0>]

# %%
import seaborn as sns

sns.countplot(sales, x = "section")
# Out:
# <Axes: xlabel='section', ylabel='count'>
